# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from thor_magni_tools.utils.visualization_nb import visualize_scenario

# %%
DIR_PATH = "../datasets/atc/"
SCENARIO_ID = "atc-tracking-part1"

# %%
path = os.path.join(DIR_PATH, SCENARIO_ID)
os.listdir(path)
# Out:
# ['atc-20121121.csv',
#  'atc-20121111.csv',
#  'atc-20121114.csv',
#  'atc-20121107.csv',
#  'atc-20121118.csv',
#  'atc-20121024.csv',
#  'atc-20121104.csv',
#  'atc-20121031.csv',
#  'atc-20121125.csv',
#  'atc-20121028.csv']

# %%
raw_df = pd.read_csv(
    os.path.join(path, "atc-20121121.csv"),
    names=[
        "Time",
        "ag_id",
        "x",
        "y",
        "z",
        "velocity",
        "angle of motion",
        "facing angle",
    ],
    index_col=0,
)

# %%
raw_df.head(5)
# Out:
#                 ag_id      x      y         z  velocity  angle of motion  \
# Time
# 1.353456e+09  9015402 -19924    786  1883.475   643.340           -2.594
# 1.353456e+09  9015900 -19204   -479  1218.358   514.031            0.166
# 1.353456e+09  9020000 -20018   -858  1548.623   796.307            1.672
# 1.353456e+09  9021000   8130   -653  1742.644  1793.719            1.843
# 1.353456e+09  9021900  34441 -19403  1727.373  1210.414           -0.260
#
#               facing angle
# Time
# 1.353456e+09        -2.620
# 1.353456e+09         0.099
# 1.353456e+09         1.664
# 1.353456e+09         1.867
# 1.353456e+09        -0.202

# %%
raw_df = raw_df[raw_df["ag_id"] > 0]

# %%
visualize_scenario(raw_df.iloc[:100000])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
raw_df.index
# Out:
# Float64Index([1353456163.856, 1353456163.856, 1353456163.856, 1353456163.856,
#               1353456163.856, 1353456163.856, 1353456163.856, 1353456163.856,
#               1353456163.856, 1353456163.856,
#               ...
#               1353497885.814, 1353497885.814, 1353497885.814, 1353497885.814,
#               1353497885.814, 1353497885.814, 1353497885.814, 1353497885.814,
#               1353497885.814, 1353497885.814],
#              dtype='float64', name='Time', length=25887021)
