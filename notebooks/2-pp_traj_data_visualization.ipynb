# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from IPython.display import HTML
from celluloid import Camera

from thor_magni_tools.utils.load import load_csv_metadata, preprocessing_header
from thor_magni_tools.preprocessing.filtering import Filterer3DOF
from thor_magni_tools.preprocessing import TrajectoriesReprocessor
from thor_magni_tools.utils.visualization_nb import visualize_scenario

# %%
DIR_PATH = "../datasets/thor_magni_zenodo/"
SCENARIO_ID = "Scenario_1"

# %%
raw_df, header_dict = load_csv_metadata(
    os.path.join(DIR_PATH, SCENARIO_ID, "THOR-Magni_120522_SC1B_R1.csv")
)
# Out:
# /home/tmr/Documents/PhD/My_PhD/code/thor-magni-tools/thor_magni_tools/utils/load.py:22: DtypeWarning: Columns (231,232,233,239,240,241) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_df = pd.read_csv(

# %%
new_header_dict = preprocessing_header(header_dict)
traj_metadata = new_header_dict["SENSOR_DATA"]["TRAJECTORIES"]["METADATA"]

# %% [markdown]
# ### Filtering best markers

# %%
roles = {k: metadata["ROLE"] for k, metadata in traj_metadata.items()}
best_markers_traj = Filterer3DOF.filter_best_markers(raw_df, roles)

# %% [markdown]
# ### Visualization

# %%
visualize_scenario(best_markers_traj, roles)

# %% [markdown]
# ## Preprocessing

# %%
pp_df = TrajectoriesReprocessor.interpolate(best_markers_traj, 100)  # max  1s interpolation

# %%
visualize_scenario(pp_df, roles)

# %% [markdown]
# # Animation (take some time depedning on the number of frames)

# %%
cmap = get_cmap("tab20")
colors_agent = {
    body_name: cmap.colors[i] for i, body_name in enumerate(traj_metadata.keys())
}

# %%
fig, ax = plt.subplots(figsize=(16, 8))
ax.set_ylabel("Y/mm", fontsize=29)
ax.set_xlabel("X/mm", fontsize=29)

camera = Camera(fig)

for frame in pp_df.frame_id.iloc[:2000]:
    frame_data = pp_df[pp_df["frame_id"] == frame]
    agents_frame = frame_data.ag_id.unique()

    for agent in agents_frame:
        agent_data = frame_data[frame_data["ag_id"] == agent]
        agent_role = agent_data["data_label"].iloc[0]
        if not agent_data["x"].isna().all():
            plt.scatter(
                agent_data["x"],
                agent_data["y"],
                c=np.array([colors_agent[agent]]),
                s=70,
            )
            plt.text(
                agent_data["x"]-25,
                agent_data["y"]-50,
                agent.split("_")[-1],
                size="small",
                color="black",
                weight="semibold",
            )
    camera.snap()

# Stop the static plot from displaying
plt.close()

# %%
anim = camera.animate(interval = 10, repeat = True, repeat_delay = 500)
HTML(anim.to_html5_video())
# Out:
# <video width="1600" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...
